# %%
# !pip install PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import os
from google.colab import drive
MOUNTPOINT = '/content/gdrive'
DATADIR = os.path.join(MOUNTPOINT, 'MyDrive', 'models')
drive.mount(MOUNTPOINT)
# Out:
# ...
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Mounted at /content/gdrive

# %% [markdown]
# # Change to .bin format

# %%
# !pip install safetensors==0.3.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.1
#     Uninstalling safetensors-0.4.1:
#       Successfully uninstalled safetensors-0.4.1
# ...

# %%
import torch
from safetensors.torch import load_file

# Đường dẫn đến file .safetensors
safetensors_path = "/content/gdrive/MyDrive/chatbot-pm/checkpoint-llama-filtered/final_checkpoint/adapter_model.safetensors"

# Tải mô hình từ file .safetensors
model_state_dict = load_file(safetensors_path, device="cpu")

# Lưu mô hình vào file .bin
torch.save(model_state_dict, '/content/gdrive/MyDrive/chatbot-pm/checkpoint-llama-filtered/final_checkpoint/adapter_model.bin')

# %% [markdown]
# # Convert to GUFF, change checkpoint-dir

# %%
# !git lfs install
# !git clone https://fubaoineverland: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@huggingface.co/bkai-foundation-models/vietnamese-llama2-7b-40GB
# Out:
# Git LFS initialized.
# Cloning into 'vietnamese-llama2-7b-40GB'...
# remote: Enumerating objects: 104, done.
# remote: Total 104 (delta 0), reused 0 (delta 0), pack-reused 104
# Receiving objects: 100% (104/104), 726.43 KiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# ...
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
#
# Exiting because of "interrupt" signal.
# ^C

# %%
# !pip install huggingface_hub
from huggingface_hub import login
login("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")
# Out:
# ...
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !cp -r  "/content/gdrive/MyDrive/chatbot-pm/checkpoint-16-64-filtered/" "/content"

# %%
# Install llama.cpp
# !git clone https://github.com/ggerganov/llama.cpp
# !cd llama.cpp && git pull && make clean && LLAMA_CUBLAS=1 make
# !pip install -r llama.cpp/requirements.txt
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 13299, done.
# remote: Counting objects: 100% (13299/13299), done.
# remote: Compressing objects: 100% (4121/4121), done.
# remote: Total 13299 (delta 9308), reused 12945 (delta 9090), pack-reused 0
# Receiving objects: 100% (13299/13299), 15.59 MiB | 18.35 MiB/s, done.
# Resolving deltas: 100% (9308/9308), done.
# Already up to date.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -I. -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG  -std=c11   -fPIC -O3 -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -Wdouble-promotion
# ...

# %%
cd llama.cpp
# Out:
# /content/llama.cpp

# %%
# !python3 convert-lora-to-ggml.py /content/final_checkpoint/
# Out:
# base_model.model.model.layers.0.mlp.down_proj.lora_A.weight => blk.0.ffn_down.weight.loraA (11008, 16) float32 0.67MB
# base_model.model.model.layers.0.mlp.down_proj.lora_B.weight => blk.0.ffn_down.weight.loraB (4096, 16) float32 0.25MB
# base_model.model.model.layers.0.mlp.gate_proj.lora_A.weight => blk.0.ffn_gate.weight.loraA (4096, 16) float32 0.25MB
# base_model.model.model.layers.0.mlp.gate_proj.lora_B.weight => blk.0.ffn_gate.weight.loraB (11008, 16) float32 0.67MB
# base_model.model.model.layers.0.mlp.up_proj.lora_A.weight => blk.0.ffn_up.weight.loraA (4096, 16) float32 0.25MB
# base_model.model.model.layers.0.mlp.up_proj.lora_B.weight => blk.0.ffn_up.weight.loraB (11008, 16) float32 0.67MB
# base_model.model.model.layers.0.self_attn.k_proj.lora_A.weight => blk.0.attn_k.weight.loraA (4096, 16) float32 0.25MB
# base_model.model.model.layers.0.self_attn.k_proj.lora_B.weight => blk.0.attn_k.weight.loraB (4096, 16) float32 0.25MB
# ...

# %%
# !cp /content/final_checkpoint/* /content/vietnamese-llama2-7b-40GB
# Out:
# cp: cannot stat '/content/final_checkpoint/*': No such file or directory

# %%
# !python3 convert.py /content/vietnamese-llama2-7b-40GB --vocab-dir="/content/vietnamese-llama2-7b-40GB/pt_lora_model"
# Out:
# Loading model file /content/vietnamese-llama2-7b-40GB/model-00001-of-00002.safetensors
# Loading model file /content/vietnamese-llama2-7b-40GB/model-00001-of-00002.safetensors
# Loading model file /content/vietnamese-llama2-7b-40GB/model-00002-of-00002.safetensors
# params = Params(n_vocab=46303, n_embd=4096, n_layer=32, n_ctx=4096, n_ff=11008, n_head=32, n_head_kv=32, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=None, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=None, path_model=PosixPath('/content/vietnamese-llama2-7b-40GB'))
# Loading vocab file '/content/vietnamese-llama2-7b-40GB/pt_lora_model/tokenizer.model', type 'spm'
# Permuting layer 0
# Permuting layer 1
# Permuting layer 2
# Permuting layer 3
# Permuting layer 4
# Permuting layer 5
# Permuting layer 6
# Permuting layer 7
# Permuting layer 8
# Permuting layer 9
# Permuting layer 10
# Permuting layer 11
# Permuting layer 12
# Permuting layer 13
# Permuting layer 14
# Permuting layer 15
# ...

# %%
# !./quantize /content/vietnamese-llama2-7b-40GB/ggml-model-f16.gguf /content/vietnamese-llama2-7b-40GB/ggml-model-q8_0.gguf q8_0
# Out:
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
# main: build = 1628 (fecac45)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: quantizing '/content/vietnamese-llama2-7b-40GB/ggml-model-f16.gguf' to '/content/vietnamese-llama2-7b-40GB/ggml-model-q8_0.gguf' as Q8_0
# llama_model_loader: loaded meta data with 21 key-value pairs and 291 tensors from /content/vietnamese-llama2-7b-40GB/ggml-model-f16.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight f16      [  4096, 46303,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight f16      [ 11008,  4096,     1,     1 ]
# ...

# %%
# !./export-lora -m /content/vietnamese-llama2-7b-40GB/ggml-model-q8_0.gguf -o /content/vietnamese-llama2-7b-40GB/ggml-merged-model-q8_0.gguf -l /content/vietnamese-llama2-7b-40GB/ggml-adapter-model.bin
# Out:
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
# ..................................................................................................................................................

# %%
# !./main -m /content/checkpoint-16-64-filtered/ggml-merged-model-q4_k_m.gguf -n 30 --color -ngl 35 -ins -n -1
# Out:
# Log start
# main: build = 1632 (70f806b)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1702495136
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
# llama_model_loader: loaded meta data with 22 key-value pairs and 291 tensors from /content/checkpoint-16-64-filtered/ggml-merged-model-q4_k_m.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q4_K     [  4096, 46303,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q6_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor    3:            blk.0.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# ...

# %%
# !./main -m /content/final_checkpoint/ggml-merged-model-q8_0.gguf -n 30 --color -ngl 35 -ins -n -1
# Out:
# Log start
# main: build = 1628 (fecac45)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed  = 1702460741
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5
# llama_model_loader: loaded meta data with 22 key-value pairs and 291 tensors from /content/final_checkpoint/ggml-merged-model-q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q8_0     [  4096, 46303,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q8_0     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor    3:            blk.0.ffn_gate.weight q8_0     [  4096, 11008,     1,     1 ]
# ...

# %%
# !cp -r  "/content/vietnamese-llama2-7b-40GB/ggml-merged-model-q8_0.gguf" "/content/gdrive/MyDrive/chatbot-pm/checkpoint-llama-filtered/final_checkpoint"
